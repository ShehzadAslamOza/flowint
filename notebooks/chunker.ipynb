# %%
import boto3
import yaml
from io import BytesIO
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# AWS credentials from .env
AWS_ACCESS_KEY = os.getenv("AWS_ACCESS_KEY")
AWS_SECRET_KEY = os.getenv("AWS_SECRET_KEY")
BUCKET_NAME = os.getenv("BUCKET_NAME")


# S3 client
s3 = boto3.client(
    "s3",
    aws_access_key_id=AWS_ACCESS_KEY,
    aws_secret_access_key=AWS_SECRET_KEY
)

# %%
# Your S3 key (path to the file inside the bucket)
s3_key = "openapi-specs/ef0a6586-98c3-4d29-a587-849771eccb43_openapi.yaml"  # Replace with your actual key

# %%
# Load and parse the YAML file from S3
response = s3.get_object(Bucket=BUCKET_NAME, Key=s3_key)
yaml_content = yaml.safe_load(response["Body"].read())

# Display sample
print(yaml_content.keys())
# Out:
# dict_keys(['openapi', 'info', 'servers', 'components', 'paths'])

# %%
sum = 0
for path, content in yaml_content["paths"].items():
    sum += len(str(content))
    
print("sum:", sum)
print("avg:", sum / len(yaml_content["paths"]))
print("max:", max(len(str(content)) for path, content in yaml_content["paths"].items()))
print("min:", min(len(str(content)) for path, content in yaml_content["paths"].items()))
# Out:
# sum: 8122
# avg: 1160.2857142857142
# max: 1558
# min: 485

# %%
unique_keys = set()
for path, content in yaml_content["paths"].items():
    print("path:", path)
    print("content:", content)
    print("content_keys:", content.keys())
    unique_keys.update(content.keys())
    print("\n")
# Out:
# path: /tickets
# content: {'get': {'summary': 'Get all tickets', 'description': 'Retrieve a list of all tickets with optional filtering', 'parameters': [{'name': 'status', 'in': 'query', 'schema': {'type': 'string', 'enum': ['open', 'in-progress', 'resolved', 'closed']}, 'description': 'Filter tickets by status'}, {'name': 'priority', 'in': 'query', 'schema': {'type': 'string', 'enum': ['low', 'medium', 'high', 'urgent']}, 'description': 'Filter tickets by priority'}, {'name': 'assignedTo', 'in': 'query', 'schema': {'type': 'string'}, 'description': 'Filter tickets by assigned user ID'}], 'responses': {'200': {'description': 'List of tickets', 'content': {'application/json': {'schema': {'type': 'array', 'items': {'$ref': '#/components/schemas/Ticket'}}}}}}}, 'post': {'summary': 'Create a new ticket', 'security': [{'basicAuth': []}], 'requestBody': {'required': True, 'content': {'application/json': {'schema': {'type': 'object', 'properties': {'title': {'type': 'string'}, 'description': {'type': 'string'}, 'priority': {'type': 'string', 'enum': ['low', 'medium', 'high', 'urgent'], 'default': 'medium'}}, 'required': ['title', 'description']}}}}, 'responses': {'201': {'description': 'Ticket created successfully', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Ticket'}}}}, '400': {'description': 'Invalid input', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}, '401': {'description': 'Unauthorized', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}}
# content_keys: dict_keys(['get', 'post'])
#
#
# path: /tickets/{ticketId}
# content: {'parameters': [{'name': 'ticketId', 'in': 'path', 'required': True, 'schema': {'type': 'string', 'format': 'uuid'}, 'description': 'ID of the ticket'}], 'get': {'summary': 'Get ticket details', 'responses': {'200': {'description': 'Ticket details', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Ticket'}}}}, '404': {'description': 'Ticket not found', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}, 'put': {'summary': 'Update ticket', 'security': [{'basicAuth': []}], 'requestBody': {'required': True, 'content': {'application/json': {'schema': {'type': 'object', 'properties': {'title': {'type': 'string'}, 'description': {'type': 'string'}, 'assignedTo': {'type': 'string'}}}}}}, 'responses': {'200': {'description': 'Ticket updated successfully', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Ticket'}}}}, '404': {'description': 'Ticket not found', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}, '401': {'description': 'Unauthorized', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}, 'delete': {'summary': 'Delete ticket', 'security': [{'basicAuth': []}], 'responses': {'204': {'description': 'Ticket deleted successfully'}, '404': {'description': 'Ticket not found', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}, '401': {'description': 'Unauthorized', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}}
# content_keys: dict_keys(['parameters', 'get', 'put', 'delete'])
#
#
# path: /tickets/{ticketId}/comments
# content: {'parameters': [{'name': 'ticketId', 'in': 'path', 'required': True, 'schema': {'type': 'string', 'format': 'uuid'}, 'description': 'ID of the ticket'}], 'get': {'summary': 'Get ticket comments', 'responses': {'200': {'description': 'List of comments', 'content': {'application/json': {'schema': {'type': 'array', 'items': {'$ref': '#/components/schemas/Comment'}}}}}, '404': {'description': 'Ticket not found', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}, 'post': {'summary': 'Add comment to ticket', 'security': [{'basicAuth': []}], 'requestBody': {'required': True, 'content': {'application/json': {'schema': {'type': 'object', 'properties': {'content': {'type': 'string'}}, 'required': ['content']}}}}, 'responses': {'201': {'description': 'Comment added successfully', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Comment'}}}}, '404': {'description': 'Ticket not found', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}, '401': {'description': 'Unauthorized', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}}
# content_keys: dict_keys(['parameters', 'get', 'post'])
#
#
# path: /tickets/{ticketId}/status
# content: {'parameters': [{'name': 'ticketId', 'in': 'path', 'required': True, 'schema': {'type': 'string', 'format': 'uuid'}, 'description': 'ID of the ticket'}], 'get': {'summary': 'Get ticket status', 'responses': {'200': {'description': 'Ticket status', 'content': {'application/json': {'schema': {'type': 'object', 'properties': {'status': {'type': 'string', 'enum': ['open', 'in-progress', 'resolved', 'closed']}}}}}}, '404': {'description': 'Ticket not found', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}, 'put': {'summary': 'Update ticket status', 'security': [{'basicAuth': []}], 'requestBody': {'required': True, 'content': {'application/json': {'schema': {'type': 'object', 'properties': {'status': {'type': 'string', 'enum': ['open', 'in-progress', 'resolved', 'closed']}}, 'required': ['status']}}}}, 'responses': {'200': {'description': 'Status updated successfully', 'content': {'application/json': {'schema': {'type': 'object', 'properties': {'status': {'type': 'string', 'enum': ['open', 'in-progress', 'resolved', 'closed']}}}}}}, '404': {'description': 'Ticket not found', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}, '401': {'description': 'Unauthorized', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}}
# content_keys: dict_keys(['parameters', 'get', 'put'])
#
#
# path: /tickets/{ticketId}/priority
# content: {'parameters': [{'name': 'ticketId', 'in': 'path', 'required': True, 'schema': {'type': 'string', 'format': 'uuid'}, 'description': 'ID of the ticket'}], 'get': {'summary': 'Get ticket priority', 'responses': {'200': {'description': 'Ticket priority', 'content': {'application/json': {'schema': {'type': 'object', 'properties': {'priority': {'type': 'string', 'enum': ['low', 'medium', 'high', 'urgent']}}}}}}, '404': {'description': 'Ticket not found', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}, 'put': {'summary': 'Update ticket priority', 'security': [{'basicAuth': []}], 'requestBody': {'required': True, 'content': {'application/json': {'schema': {'type': 'object', 'properties': {'priority': {'type': 'string', 'enum': ['low', 'medium', 'high', 'urgent']}}, 'required': ['priority']}}}}, 'responses': {'200': {'description': 'Priority updated successfully', 'content': {'application/json': {'schema': {'type': 'object', 'properties': {'priority': {'type': 'string', 'enum': ['low', 'medium', 'high', 'urgent']}}}}}}, '404': {'description': 'Ticket not found', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}, '401': {'description': 'Unauthorized', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}}
# content_keys: dict_keys(['parameters', 'get', 'put'])
#
#
# path: /users
# content: {'get': {'summary': 'Get all users', 'security': [{'basicAuth': []}], 'responses': {'200': {'description': 'List of users', 'content': {'application/json': {'schema': {'type': 'array', 'items': {'$ref': '#/components/schemas/User'}}}}}, '401': {'description': 'Unauthorized', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}, '403': {'description': 'Forbidden', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}}
# content_keys: dict_keys(['get'])
#
#
# path: /users/{userId}
# content: {'parameters': [{'name': 'userId', 'in': 'path', 'required': True, 'schema': {'type': 'string'}, 'description': 'ID of the user'}], 'get': {'summary': 'Get user details', 'security': [{'basicAuth': []}], 'responses': {'200': {'description': 'User details', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/User'}}}}, '401': {'description': 'Unauthorized', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}, '403': {'description': 'Forbidden', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}, '404': {'description': 'User not found', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}}
# content_keys: dict_keys(['parameters', 'get'])

# %%
for key, content in yaml_content["paths"].items():
    print({key:content})
    print("\n")
# Out:
# {'/tickets': {'get': {'summary': 'Get all tickets', 'description': 'Retrieve a list of all tickets with optional filtering', 'parameters': [{'name': 'status', 'in': 'query', 'schema': {'type': 'string', 'enum': ['open', 'in-progress', 'resolved', 'closed']}, 'description': 'Filter tickets by status'}, {'name': 'priority', 'in': 'query', 'schema': {'type': 'string', 'enum': ['low', 'medium', 'high', 'urgent']}, 'description': 'Filter tickets by priority'}, {'name': 'assignedTo', 'in': 'query', 'schema': {'type': 'string'}, 'description': 'Filter tickets by assigned user ID'}], 'responses': {'200': {'description': 'List of tickets', 'content': {'application/json': {'schema': {'type': 'array', 'items': {'$ref': '#/components/schemas/Ticket'}}}}}}}, 'post': {'summary': 'Create a new ticket', 'security': [{'basicAuth': []}], 'requestBody': {'required': True, 'content': {'application/json': {'schema': {'type': 'object', 'properties': {'title': {'type': 'string'}, 'description': {'type': 'string'}, 'priority': {'type': 'string', 'enum': ['low', 'medium', 'high', 'urgent'], 'default': 'medium'}}, 'required': ['title', 'description']}}}}, 'responses': {'201': {'description': 'Ticket created successfully', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Ticket'}}}}, '400': {'description': 'Invalid input', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}, '401': {'description': 'Unauthorized', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}}}
#
#
# {'/tickets/{ticketId}': {'parameters': [{'name': 'ticketId', 'in': 'path', 'required': True, 'schema': {'type': 'string', 'format': 'uuid'}, 'description': 'ID of the ticket'}], 'get': {'summary': 'Get ticket details', 'responses': {'200': {'description': 'Ticket details', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Ticket'}}}}, '404': {'description': 'Ticket not found', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}, 'put': {'summary': 'Update ticket', 'security': [{'basicAuth': []}], 'requestBody': {'required': True, 'content': {'application/json': {'schema': {'type': 'object', 'properties': {'title': {'type': 'string'}, 'description': {'type': 'string'}, 'assignedTo': {'type': 'string'}}}}}}, 'responses': {'200': {'description': 'Ticket updated successfully', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Ticket'}}}}, '404': {'description': 'Ticket not found', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}, '401': {'description': 'Unauthorized', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}, 'delete': {'summary': 'Delete ticket', 'security': [{'basicAuth': []}], 'responses': {'204': {'description': 'Ticket deleted successfully'}, '404': {'description': 'Ticket not found', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}, '401': {'description': 'Unauthorized', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}}}
#
#
# {'/tickets/{ticketId}/comments': {'parameters': [{'name': 'ticketId', 'in': 'path', 'required': True, 'schema': {'type': 'string', 'format': 'uuid'}, 'description': 'ID of the ticket'}], 'get': {'summary': 'Get ticket comments', 'responses': {'200': {'description': 'List of comments', 'content': {'application/json': {'schema': {'type': 'array', 'items': {'$ref': '#/components/schemas/Comment'}}}}}, '404': {'description': 'Ticket not found', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}, 'post': {'summary': 'Add comment to ticket', 'security': [{'basicAuth': []}], 'requestBody': {'required': True, 'content': {'application/json': {'schema': {'type': 'object', 'properties': {'content': {'type': 'string'}}, 'required': ['content']}}}}, 'responses': {'201': {'description': 'Comment added successfully', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Comment'}}}}, '404': {'description': 'Ticket not found', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}, '401': {'description': 'Unauthorized', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}}}
#
#
# {'/tickets/{ticketId}/status': {'parameters': [{'name': 'ticketId', 'in': 'path', 'required': True, 'schema': {'type': 'string', 'format': 'uuid'}, 'description': 'ID of the ticket'}], 'get': {'summary': 'Get ticket status', 'responses': {'200': {'description': 'Ticket status', 'content': {'application/json': {'schema': {'type': 'object', 'properties': {'status': {'type': 'string', 'enum': ['open', 'in-progress', 'resolved', 'closed']}}}}}}, '404': {'description': 'Ticket not found', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}, 'put': {'summary': 'Update ticket status', 'security': [{'basicAuth': []}], 'requestBody': {'required': True, 'content': {'application/json': {'schema': {'type': 'object', 'properties': {'status': {'type': 'string', 'enum': ['open', 'in-progress', 'resolved', 'closed']}}, 'required': ['status']}}}}, 'responses': {'200': {'description': 'Status updated successfully', 'content': {'application/json': {'schema': {'type': 'object', 'properties': {'status': {'type': 'string', 'enum': ['open', 'in-progress', 'resolved', 'closed']}}}}}}, '404': {'description': 'Ticket not found', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}, '401': {'description': 'Unauthorized', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}}}
#
#
# {'/tickets/{ticketId}/priority': {'parameters': [{'name': 'ticketId', 'in': 'path', 'required': True, 'schema': {'type': 'string', 'format': 'uuid'}, 'description': 'ID of the ticket'}], 'get': {'summary': 'Get ticket priority', 'responses': {'200': {'description': 'Ticket priority', 'content': {'application/json': {'schema': {'type': 'object', 'properties': {'priority': {'type': 'string', 'enum': ['low', 'medium', 'high', 'urgent']}}}}}}, '404': {'description': 'Ticket not found', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}, 'put': {'summary': 'Update ticket priority', 'security': [{'basicAuth': []}], 'requestBody': {'required': True, 'content': {'application/json': {'schema': {'type': 'object', 'properties': {'priority': {'type': 'string', 'enum': ['low', 'medium', 'high', 'urgent']}}, 'required': ['priority']}}}}, 'responses': {'200': {'description': 'Priority updated successfully', 'content': {'application/json': {'schema': {'type': 'object', 'properties': {'priority': {'type': 'string', 'enum': ['low', 'medium', 'high', 'urgent']}}}}}}, '404': {'description': 'Ticket not found', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}, '401': {'description': 'Unauthorized', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}}}
#
#
# {'/users': {'get': {'summary': 'Get all users', 'security': [{'basicAuth': []}], 'responses': {'200': {'description': 'List of users', 'content': {'application/json': {'schema': {'type': 'array', 'items': {'$ref': '#/components/schemas/User'}}}}}, '401': {'description': 'Unauthorized', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}, '403': {'description': 'Forbidden', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}}}
#
#
# {'/users/{userId}': {'parameters': [{'name': 'userId', 'in': 'path', 'required': True, 'schema': {'type': 'string'}, 'description': 'ID of the user'}], 'get': {'summary': 'Get user details', 'security': [{'basicAuth': []}], 'responses': {'200': {'description': 'User details', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/User'}}}}, '401': {'description': 'Unauthorized', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}, '403': {'description': 'Forbidden', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}, '404': {'description': 'User not found', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Error'}}}}}}}}

# %%
import yaml

def collect_all_parameters(path_item, operation):
    path_params = path_item.get("parameters", [])
    op_params = operation.get("parameters", [])
    return path_params + op_params

def format_parameters(params):
    if not params:
        return "None"
    lines = []
    for p in params:
        name = p.get("name")
        location = p.get("in")
        required = p.get("required", False)
        description = p.get("description", "")
        schema = p.get("schema", {})
        type_ = schema.get("type", "unknown")
        enum = schema.get("enum")
        enum_str = f" — enum: {', '.join(enum)}" if enum else ""
        req_str = "required" if required else "optional"
        lines.append(f"- {name} ({location}, {type_}, {req_str}): {description}{enum_str}")
    return "\n".join(lines)

def format_request_body(request_body):
    if not request_body:
        return "None"
    content = request_body.get("content", {})
    if "application/json" in content:
        schema = content["application/json"].get("schema", {})
        props = schema.get("properties", {})
        required = schema.get("required", [])
        lines = []
        for name, val in props.items():
            type_ = val.get("type", "unknown")
            enum = val.get("enum")
            enum_str = f" — enum: {', '.join(enum)}" if enum else ""
            req_str = "required" if name in required else "optional"
            lines.append(f"- {name} ({type_}, {req_str}){enum_str}")
        return "\n".join(lines)
    return "Unsupported content type"

def format_responses(responses):
    lines = []
    for status, resp in responses.items():
        desc = resp.get("description", "")
        lines.append(f"- {status}: {desc}")
    return "\n".join(lines)

def describe_security(security, security_schemes):
    if not security:
        return "None"
    descriptions = []
    for scheme_group in security:
        for name in scheme_group:
            scheme = security_schemes.get(name, {})
            scheme_type = scheme.get("type", "unknown")
            description = f"{name} (type: {scheme_type}"
            if "scheme" in scheme:
                description += f", scheme: {scheme['scheme']}"
            if "bearerFormat" in scheme:
                description += f", bearerFormat: {scheme['bearerFormat']}"
            description += ")"
            descriptions.append(description)
    return "\n".join(descriptions)

def create_openapi_chunks(yaml_content, integration_name="generic"):
    chunks = []
    paths = yaml_content.get("paths", {})
    security_schemes = yaml_content.get("components", {}).get("securitySchemes", {})

    for path, path_item in paths.items():
        for method in path_item:
            if method not in ["get", "post", "put", "delete", "patch", "options", "head"]:
                continue
            operation = path_item[method]

            summary = operation.get("summary", "")
            description = operation.get("description", "")
            all_params = collect_all_parameters(path_item, operation)
            request_body = operation.get("requestBody")
            responses = operation.get("responses", {})
            security = operation.get("security", [])

            chunk = f"""Integration: {integration_name}
Authentication Required: {describe_security(security, security_schemes)}
Path: {path}
Method: {method.upper()}
Summary: {summary}
Description: {description}

Parameters:
{format_parameters(all_params)}

Request Body:
{format_request_body(request_body)}

Responses:
{format_responses(responses)}
"""
            chunks.append({
                "id": f"{integration_name}:{method.upper()}:{path}",
                "text": chunk,
                "summary": summary
            })

    return chunks

# %%
INTEGRATION_NAME = "TICKETING SYSTEM"
chunks = create_openapi_chunks(yaml_content, integration_name=INTEGRATION_NAME)

for a, i in enumerate(chunks):
    print(i["id"])
    print(i["text"])
    print("\n")
# Out:
# TICKETING SYSTEM:GET:/tickets
# Integration: TICKETING SYSTEM
# Authentication Required: None
# Path: /tickets
# Method: GET
# Summary: Get all tickets
# Description: Retrieve a list of all tickets with optional filtering
#
# Parameters:
# - status (query, string, optional): Filter tickets by status — enum: open, in-progress, resolved, closed
# - priority (query, string, optional): Filter tickets by priority — enum: low, medium, high, urgent
# - assignedTo (query, string, optional): Filter tickets by assigned user ID
#
# Request Body:
# None
#
# Responses:
# - 200: List of tickets
#
#
#
# TICKETING SYSTEM:POST:/tickets
# Integration: TICKETING SYSTEM
# Authentication Required: basicAuth (type: http, scheme: basic)
# Path: /tickets
# Method: POST
# Summary: Create a new ticket
# Description:
#
# Parameters:
# None
#
# Request Body:
# - title (string, required)
# - description (string, required)
# - priority (string, optional) — enum: low, medium, high, urgent
#
# Responses:
# - 201: Ticket created successfully
# - 400: Invalid input
# - 401: Unauthorized
#
#
#
# TICKETING SYSTEM:GET:/tickets/{ticketId}
# Integration: TICKETING SYSTEM
# Authentication Required: None
# Path: /tickets/{ticketId}
# Method: GET
# Summary: Get ticket details
# Description:
#
# Parameters:
# - ticketId (path, string, required): ID of the ticket
#
# Request Body:
# None
#
# Responses:
# - 200: Ticket details
# - 404: Ticket not found
#
#
#
# TICKETING SYSTEM:PUT:/tickets/{ticketId}
# Integration: TICKETING SYSTEM
# Authentication Required: basicAuth (type: http, scheme: basic)
# Path: /tickets/{ticketId}
# Method: PUT
# Summary: Update ticket
# Description:
#
# Parameters:
# - ticketId (path, string, required): ID of the ticket
#
# Request Body:
# - title (string, optional)
# - description (string, optional)
# - assignedTo (string, optional)
#
# Responses:
# - 200: Ticket updated successfully
# - 404: Ticket not found
# - 401: Unauthorized
#
#
#
# TICKETING SYSTEM:DELETE:/tickets/{ticketId}
# Integration: TICKETING SYSTEM
# Authentication Required: basicAuth (type: http, scheme: basic)
# Path: /tickets/{ticketId}
# Method: DELETE
# Summary: Delete ticket
# Description:
#
# Parameters:
# - ticketId (path, string, required): ID of the ticket
#
# Request Body:
# None
#
# Responses:
# - 204: Ticket deleted successfully
# - 404: Ticket not found
# - 401: Unauthorized
#
#
#
# TICKETING SYSTEM:GET:/tickets/{ticketId}/comments
# Integration: TICKETING SYSTEM
# Authentication Required: None
# Path: /tickets/{ticketId}/comments
# Method: GET
# Summary: Get ticket comments
# Description:
#
# Parameters:
# - ticketId (path, string, required): ID of the ticket
#
# Request Body:
# None
#
# Responses:
# - 200: List of comments
# - 404: Ticket not found
#
#
#
# TICKETING SYSTEM:POST:/tickets/{ticketId}/comments
# Integration: TICKETING SYSTEM
# Authentication Required: basicAuth (type: http, scheme: basic)
# Path: /tickets/{ticketId}/comments
# Method: POST
# Summary: Add comment to ticket
# Description:
#
# Parameters:
# - ticketId (path, string, required): ID of the ticket
#
# Request Body:
# - content (string, required)
#
# Responses:
# - 201: Comment added successfully
# - 404: Ticket not found
# - 401: Unauthorized
#
#
#
# TICKETING SYSTEM:GET:/tickets/{ticketId}/status
# Integration: TICKETING SYSTEM
# Authentication Required: None
# Path: /tickets/{ticketId}/status
# Method: GET
# Summary: Get ticket status
# Description:
#
# Parameters:
# - ticketId (path, string, required): ID of the ticket
#
# Request Body:
# None
#
# Responses:
# - 200: Ticket status
# - 404: Ticket not found
#
#
#
# TICKETING SYSTEM:PUT:/tickets/{ticketId}/status
# Integration: TICKETING SYSTEM
# Authentication Required: basicAuth (type: http, scheme: basic)
# Path: /tickets/{ticketId}/status
# Method: PUT
# Summary: Update ticket status
# Description:
#
# Parameters:
# - ticketId (path, string, required): ID of the ticket
#
# Request Body:
# - status (string, required) — enum: open, in-progress, resolved, closed
#
# Responses:
# - 200: Status updated successfully
# - 404: Ticket not found
# - 401: Unauthorized
#
#
#
# TICKETING SYSTEM:GET:/tickets/{ticketId}/priority
# Integration: TICKETING SYSTEM
# Authentication Required: None
# Path: /tickets/{ticketId}/priority
# Method: GET
# Summary: Get ticket priority
# Description:
#
# Parameters:
# - ticketId (path, string, required): ID of the ticket
#
# Request Body:
# None
#
# Responses:
# - 200: Ticket priority
# - 404: Ticket not found
#
#
#
# TICKETING SYSTEM:PUT:/tickets/{ticketId}/priority
# Integration: TICKETING SYSTEM
# Authentication Required: basicAuth (type: http, scheme: basic)
# Path: /tickets/{ticketId}/priority
# Method: PUT
# Summary: Update ticket priority
# Description:
#
# Parameters:
# - ticketId (path, string, required): ID of the ticket
#
# Request Body:
# - priority (string, required) — enum: low, medium, high, urgent
#
# Responses:
# - 200: Priority updated successfully
# - 404: Ticket not found
# - 401: Unauthorized
#
#
#
# TICKETING SYSTEM:GET:/users
# Integration: TICKETING SYSTEM
# Authentication Required: basicAuth (type: http, scheme: basic)
# Path: /users
# Method: GET
# Summary: Get all users
# Description:
#
# Parameters:
# None
#
# Request Body:
# None
#
# Responses:
# - 200: List of users
# - 401: Unauthorized
# - 403: Forbidden
#
#
#
# TICKETING SYSTEM:GET:/users/{userId}
# Integration: TICKETING SYSTEM
# Authentication Required: basicAuth (type: http, scheme: basic)
# Path: /users/{userId}
# Method: GET
# Summary: Get user details
# Description:
#
# Parameters:
# - userId (path, string, required): ID of the user
#
# Request Body:
# None
#
# Responses:
# - 200: User details
# - 401: Unauthorized
# - 403: Forbidden
# - 404: User not found

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embedding_model = GoogleGenerativeAIEmbeddings(
    model="models/embedding-001",
    google_api_key= os.getenv("GOOGLE_API_KEY")
)

# %%
from langchain.schema import Document

all_docs = [
    Document(
        page_content=chunk["text"],
        metadata={
            "id": chunk["id"],
            "method": chunk["id"].split(":")[1],
            "path": chunk["id"].split(":")[2],
            "integration": INTEGRATION_NAME,
            "summary": chunk["summary"],
        }
    )
    for chunk in chunks
]

# %%
print(all_docs)
# Out:
# [Document(metadata={'id': 'TICKETING SYSTEM:GET:/tickets', 'method': 'GET', 'path': '/tickets', 'integration': 'TICKETING SYSTEM', 'summary': 'Get all tickets'}, page_content='Integration: TICKETING SYSTEM\nAuthentication Required: None\nPath: /tickets\nMethod: GET\nSummary: Get all tickets\nDescription: Retrieve a list of all tickets with optional filtering\n\nParameters:\n- status (query, string, optional): Filter tickets by status — enum: open, in-progress, resolved, closed\n- priority (query, string, optional): Filter tickets by priority — enum: low, medium, high, urgent\n- assignedTo (query, string, optional): Filter tickets by assigned user ID\n\nRequest Body:\nNone\n\nResponses:\n- 200: List of tickets\n'), Document(metadata={'id': 'TICKETING SYSTEM:POST:/tickets', 'method': 'POST', 'path': '/tickets', 'integration': 'TICKETING SYSTEM', 'summary': 'Create a new ticket'}, page_content='Integration: TICKETING SYSTEM\nAuthentication Required: basicAuth (type: http, scheme: basic)\nPath: /tickets\nMethod: POST\nSummary: Create a new ticket\nDescription: \n\nParameters:\nNone\n\nRequest Body:\n- title (string, required)\n- description (string, required)\n- priority (string, optional) — enum: low, medium, high, urgent\n\nResponses:\n- 201: Ticket created successfully\n- 400: Invalid input\n- 401: Unauthorized\n'), Document(metadata={'id': 'TICKETING SYSTEM:GET:/tickets/{ticketId}', 'method': 'GET', 'path': '/tickets/{ticketId}', 'integration': 'TICKETING SYSTEM', 'summary': 'Get ticket details'}, page_content='Integration: TICKETING SYSTEM\nAuthentication Required: None\nPath: /tickets/{ticketId}\nMethod: GET\nSummary: Get ticket details\nDescription: \n\nParameters:\n- ticketId (path, string, required): ID of the ticket\n\nRequest Body:\nNone\n\nResponses:\n- 200: Ticket details\n- 404: Ticket not found\n'), Document(metadata={'id': 'TICKETING SYSTEM:PUT:/tickets/{ticketId}', 'method': 'PUT', 'path': '/tickets/{ticketId}', 'integration': 'TICKETING SYSTEM', 'summary': 'Update ticket'}, page_content='Integration: TICKETING SYSTEM\nAuthentication Required: basicAuth (type: http, scheme: basic)\nPath: /tickets/{ticketId}\nMethod: PUT\nSummary: Update ticket\nDescription: \n\nParameters:\n- ticketId (path, string, required): ID of the ticket\n\nRequest Body:\n- title (string, optional)\n- description (string, optional)\n- assignedTo (string, optional)\n\nResponses:\n- 200: Ticket updated successfully\n- 404: Ticket not found\n- 401: Unauthorized\n'), Document(metadata={'id': 'TICKETING SYSTEM:DELETE:/tickets/{ticketId}', 'method': 'DELETE', 'path': '/tickets/{ticketId}', 'integration': 'TICKETING SYSTEM', 'summary': 'Delete ticket'}, page_content='Integration: TICKETING SYSTEM\nAuthentication Required: basicAuth (type: http, scheme: basic)\nPath: /tickets/{ticketId}\nMethod: DELETE\nSummary: Delete ticket\nDescription: \n\nParameters:\n- ticketId (path, string, required): ID of the ticket\n\nRequest Body:\nNone\n\nResponses:\n- 204: Ticket deleted successfully\n- 404: Ticket not found\n- 401: Unauthorized\n'), Document(metadata={'id': 'TICKETING SYSTEM:GET:/tickets/{ticketId}/comments', 'method': 'GET', 'path': '/tickets/{ticketId}/comments', 'integration': 'TICKETING SYSTEM', 'summary': 'Get ticket comments'}, page_content='Integration: TICKETING SYSTEM\nAuthentication Required: None\nPath: /tickets/{ticketId}/comments\nMethod: GET\nSummary: Get ticket comments\nDescription: \n\nParameters:\n- ticketId (path, string, required): ID of the ticket\n\nRequest Body:\nNone\n\nResponses:\n- 200: List of comments\n- 404: Ticket not found\n'), Document(metadata={'id': 'TICKETING SYSTEM:POST:/tickets/{ticketId}/comments', 'method': 'POST', 'path': '/tickets/{ticketId}/comments', 'integration': 'TICKETING SYSTEM', 'summary': 'Add comment to ticket'}, page_content='Integration: TICKETING SYSTEM\nAuthentication Required: basicAuth (type: http, scheme: basic)\nPath: /tickets/{ticketId}/comments\nMethod: POST\nSummary: Add comment to ticket\n ...

# %%
from langchain_pinecone import PineconeVectorStore

vector_store = PineconeVectorStore(
    index_name= os.getenv("PINECONE_INDEX"),
    embedding=embedding_model,
    pinecone_api_key= os.getenv("PINECONE_API_KEY")
)

# %%
# vector_store.delete(delete_all=)

# %%
all_docs
# Out:
# [Document(metadata={'id': 'TICKETING SYSTEM:GET:/tickets', 'method': 'GET', 'path': '/tickets', 'integration': 'TICKETING SYSTEM', 'summary': 'Get all tickets'}, page_content='Integration: TICKETING SYSTEM\nAuthentication Required: None\nPath: /tickets\nMethod: GET\nSummary: Get all tickets\nDescription: Retrieve a list of all tickets with optional filtering\n\nParameters:\n- status (query, string, optional): Filter tickets by status — enum: open, in-progress, resolved, closed\n- priority (query, string, optional): Filter tickets by priority — enum: low, medium, high, urgent\n- assignedTo (query, string, optional): Filter tickets by assigned user ID\n\nRequest Body:\nNone\n\nResponses:\n- 200: List of tickets\n'),
#  Document(metadata={'id': 'TICKETING SYSTEM:POST:/tickets', 'method': 'POST', 'path': '/tickets', 'integration': 'TICKETING SYSTEM', 'summary': 'Create a new ticket'}, page_content='Integration: TICKETING SYSTEM\nAuthentication Required: basicAuth (type: http, scheme: basic)\nPath: /tickets\nMethod: POST\nSummary: Create a new ticket\nDescription: \n\nParameters:\nNone\n\nRequest Body:\n- title (string, required)\n- description (string, required)\n- priority (string, optional) — enum: low, medium, high, urgent\n\nResponses:\n- 201: Ticket created successfully\n- 400: Invalid input\n- 401: Unauthorized\n'),
#  Document(metadata={'id': 'TICKETING SYSTEM:GET:/tickets/{ticketId}', 'method': 'GET', 'path': '/tickets/{ticketId}', 'integration': 'TICKETING SYSTEM', 'summary': 'Get ticket details'}, page_content='Integration: TICKETING SYSTEM\nAuthentication Required: None\nPath: /tickets/{ticketId}\nMethod: GET\nSummary: Get ticket details\nDescription: \n\nParameters:\n- ticketId (path, string, required): ID of the ticket\n\nRequest Body:\nNone\n\nResponses:\n- 200: Ticket details\n- 404: Ticket not found\n'),
#  Document(metadata={'id': 'TICKETING SYSTEM:PUT:/tickets/{ticketId}', 'method': 'PUT', 'path': '/tickets/{ticketId}', 'integration': 'TICKETING SYSTEM', 'summary': 'Update ticket'}, page_content='Integration: TICKETING SYSTEM\nAuthentication Required: basicAuth (type: http, scheme: basic)\nPath: /tickets/{ticketId}\nMethod: PUT\nSummary: Update ticket\nDescription: \n\nParameters:\n- ticketId (path, string, required): ID of the ticket\n\nRequest Body:\n- title (string, optional)\n- description (string, optional)\n- assignedTo (string, optional)\n\nResponses:\n- 200: Ticket updated successfully\n- 404: Ticket not found\n- 401: Unauthorized\n'),
#  Document(metadata={'id': 'TICKETING SYSTEM:DELETE:/tickets/{ticketId}', 'method': 'DELETE', 'path': '/tickets/{ticketId}', 'integration': 'TICKETING SYSTEM', 'summary': 'Delete ticket'}, page_content='Integration: TICKETING SYSTEM\nAuthentication Required: basicAuth (type: http, scheme: basic)\nPath: /tickets/{ticketId}\nMethod: DELETE\nSummary: Delete ticket\nDescription: \n\nParameters:\n- ticketId (path, string, required): ID of the ticket\n\nRequest Body:\nNone\n\nResponses:\n- 204: Ticket deleted successfully\n- 404: Ticket not found\n- 401: Unauthorized\n'),
#  Document(metadata={'id': 'TICKETING SYSTEM:GET:/tickets/{ticketId}/comments', 'method': 'GET', 'path': '/tickets/{ticketId}/comments', 'integration': 'TICKETING SYSTEM', 'summary': 'Get ticket comments'}, page_content='Integration: TICKETING SYSTEM\nAuthentication Required: None\nPath: /tickets/{ticketId}/comments\nMethod: GET\nSummary: Get ticket comments\nDescription: \n\nParameters:\n- ticketId (path, string, required): ID of the ticket\n\nRequest Body:\nNone\n\nResponses:\n- 200: List of comments\n- 404: Ticket not found\n'),
#  Document(metadata={'id': 'TICKETING SYSTEM:POST:/tickets/{ticketId}/comments', 'method': 'POST', 'path': '/tickets/{ticketId}/comments', 'integration': 'TICKETING SYSTEM', 'summary': 'Add comment to ticket'}, page_content='Integration: TICKETING SYSTEM\nAuthentication Required: basicAuth (type: http, scheme: basic)\nPath: /tickets/{ticketId}/comments\nMethod: POST\nSummary: Add comment to ticket\nDescription: \n\nParameters:\n- ticketId (path, string, required): ID of the ticket\n\nRequest Body:\n- content (string, required)\n\nResponses:\n- 201: Comment added successfully\n- 404: Ticket not found\n- 401: Unauthorized\n'),
#  Document(metadata={'id': 'TICKETING SYSTEM:GET:/tickets/{ticketId}/status', 'method': 'GET', 'path': '/tickets/{ticketId}/status', 'integration': 'TICKETING SYSTEM', 'summary': 'Get ticket status'}, page_content='Integration: TICKETING SYSTEM\nAuthentication Required: None\nPath: /tickets/{ticketId}/status\nMethod: GET\nSummary: Get ticket status\nDescription: \n\nParameters:\n- ticketId (path, string, required): ID of the ticket\n\nRequest Body:\nNone\n\nResponses:\n- 200: Ticket status\n- 404: Ticket not found\n'),
#  Document(metadata={'id': 'TICKETING SYSTEM:PUT:/tickets/{ticketId}/status', 'method': 'PUT', 'path': '/tickets/{ticketId}/status', 'integration': 'TICKETING SYSTEM', 'summary': 'Update ticket status'}, page_content='Integration: TICKETING SYSTEM\nAuthentication Required: basicAuth (type: http, scheme: basic)\nPath: /tickets/{ticketId}/status\nMethod: PUT\nSummary: Update ticket status\nDescription: \n\nParameters:\n- ticketId (path, string, required): ID of the ticket\n\nRequest Body:\n- status (string, required) — enum: open, in-progress, resolved, closed\n\nResponses:\n- 200: Status updated successfully\n- 404: Ticket not found\n- 401: Unauthorized\n'),
#  Document(metadata={'id': 'TICKETING SYSTEM:GET:/tickets/{ticketId}/priority', 'method': 'GET', 'path': '/tickets/{ticketId}/priority', 'integration': 'TICKETING SYSTEM', 'summary': 'Get ticket priority'}, page_content='Integration: TICKETING SYSTEM\nAuthentication Required: None\nPath: /tickets/{ticketId}/priority\nMethod: GET\nSummary: Get ticket priority\nDescription: \n\nParameters:\n- ticketId (path, string, required): ID of the ticket\n\nRequest Body:\nNone\n\nResponses:\n- 200: Ticket priority\n- 404: Ticket not found\n'),
#  Document(metadata={'id': 'TICKETING SYSTEM:PUT:/tickets/{ticketId}/priority', 'method': 'PUT', 'path': '/tickets/{ticketId}/priority', 'integration': 'TICKETING SYSTEM', 'summary': 'Update ticket priority'}, page_content='Integration: TICKETING SYSTEM\nAuthentication Required: basicAuth (type: http, scheme: basic)\nPath: /tickets/{ticketId}/priority\nMethod: PUT\nSummary: Update ticket priority\nDescription: \n\nParameters:\n- ticketId (path, string, required): ID of the ticket\n\nRequest Body:\n- priority (string, required) — enum: low, medium, high, urgent\n\nResponses:\n- 200: Priority updated successfully\n- 404: Ticket not found\n- 401: Unauthorized\n'),
#  Document(metadata={'id': 'TICKETING SYSTEM:GET:/users', 'method': 'GET', 'path': '/users', 'integration': 'TICKETING SYSTEM', 'summary': 'Get all users'}, page_content='Integration: TICKETING SYSTEM\nAuthentication Required: basicAuth (type: http, scheme: basic)\nPath: /users\nMethod: GET\nSummary: Get all users\nDescription: \n\nParameters:\nNone\n\nRequest Body:\nNone\n\nResponses:\n- 200: List of users\n- 401: Unauthorized\n- 403: Forbidden\n'),
#  Document(metadata={'id': 'TICKETING SYSTEM:GET:/users/{userId}', 'method': 'GET', 'path': '/users/{userId}', 'integration': 'TICKETING SYSTEM', 'summary': 'Get user details'}, page_content='Integration: TICKETING SYSTEM\nAuthentication Required: basicAuth (type: http, scheme: basic)\nPath: /users/{userId}\nMethod: GET\nSummary: Get user details\nDescription: \n\nParameters:\n- userId (path, string, required): ID of the user\n\nRequest Body:\nNone\n\nResponses:\n- 200: User details\n- 401: Unauthorized\n- 403: Forbidden\n- 404: User not found\n')]

# %%
vector_store.add_documents(all_docs)
print(f"Successfully stored {len(all_docs)} documents with full API details")
# Out:
# Successfully stored 13 documents with full API details

# %%
INTEGRATION_NAME = "TICKETING SYSTEM"
query = "which path will give me all the tickets"
results = vector_store.similarity_search(
    query,
    k=5,
    filter={"integration": INTEGRATION_NAME}
)

for doc in results:
    print(doc.page_content)
# Out:
# Integration: TICKETING SYSTEM
# Authentication Required: None
# Path: /tickets
# Method: GET
# Summary: Get all tickets
# Description: Retrieve a list of all tickets with optional filtering
#
# Parameters:
# - status (query, string, optional): Filter tickets by status — enum: open, in-progress, resolved, closed
# - priority (query, string, optional): Filter tickets by priority — enum: low, medium, high, urgent
# - assignedTo (query, string, optional): Filter tickets by assigned user ID
#
# Request Body:
# None
#
# Responses:
# - 200: List of tickets
#
# Integration: TICKETING SYSTEM
# Authentication Required: None
# Path: /tickets/{ticketId}
# Method: GET
# Summary: Get ticket details
# Description:
#
# Parameters:
# - ticketId (path, string, required): ID of the ticket
#
# Request Body:
# None
#
# Responses:
# - 200: Ticket details
# - 404: Ticket not found
#
# Integration: TICKETING SYSTEM
# Authentication Required: None
# Path: /tickets/{ticketId}/priority
# Method: GET
# Summary: Get ticket priority
# Description:
#
# Parameters:
# - ticketId (path, string, required): ID of the ticket
#
# Request Body:
# None
#
# Responses:
# - 200: Ticket priority
# - 404: Ticket not found
#
# Integration: TICKETING SYSTEM
# Authentication Required: basicAuth (type: http, scheme: basic)
# Path: /tickets
# Method: POST
# Summary: Create a new ticket
# Description:
#
# Parameters:
# None
#
# Request Body:
# - title (string, required)
# - description (string, required)
# - priority (string, optional) — enum: low, medium, high, urgent
#
# Responses:
# - 201: Ticket created successfully
# - 400: Invalid input
# - 401: Unauthorized
#
# Integration: TICKETING SYSTEM
# Authentication Required: basicAuth (type: http, scheme: basic)
# Path: /tickets/{ticketId}
# Method: PUT
# Summary: Update ticket
# Description:
#
# Parameters:
# - ticketId (path, string, required): ID of the ticket
#
# Request Body:
# - title (string, optional)
# - description (string, optional)
# - assignedTo (string, optional)
#
# Responses:
# - 200: Ticket updated successfully
# - 404: Ticket not found
# - 401: Unauthorized
